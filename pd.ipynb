# %%
import os
import pandas as pd

def read_csv_and_display_info(file_path):
    # Read the CSV file
    data = pd.read_csv(file_path)
    
    # Display the number of rows and columns
    num_rows, num_cols = data.shape
    print(f"File: {file_path}")
    print(f"Number of rows: {num_rows}")
    print(f"Number of columns: {num_cols}")
    print()  # Empty line for better readability

# Specify the folder path
folder_path = "./Data"

# Get a list of all files in the folder
files = os.listdir(folder_path)

# Iterate over each file
for file_name in files:
    # Check if the file is a CSV file
    if file_name.endswith(".csv"):
        file_path = os.path.join(folder_path, file_name)
        read_csv_and_display_info(file_path)
# Out:
# File: ./Data\1_1.csv
# Number of rows: 29
# Number of columns: 1530
#
# File: ./Data\1_10.csv
# Number of rows: 29
# Number of columns: 1530
#
# File: ./Data\1_2.csv
# Number of rows: 29
# Number of columns: 1530
#
# File: ./Data\1_3.csv
# Number of rows: 29
# Number of columns: 1530
#
# File: ./Data\1_4.csv
# Number of rows: 29
# Number of columns: 1530
#
# File: ./Data\1_5.csv
# Number of rows: 29
# Number of columns: 1530
#
# File: ./Data\1_6.csv
# Number of rows: 29
# Number of columns: 1530
#
# File: ./Data\1_7.csv
# Number of rows: 29
# Number of columns: 1530
#
# File: ./Data\1_8.csv
# Number of rows: 29
# Number of columns: 1530
#
# File: ./Data\1_9.csv
# Number of rows: 29
# Number of columns: 1530
#
# File: ./Data\2_1.csv
# Number of rows: 29
# Number of columns: 1530
#
# File: ./Data\2_10.csv
# Number of rows: 29
# Number of columns: 1530
#
# File: ./Data\2_2.csv
# Number of rows: 29
# Number of columns: 1530
#
# File: ./Data\2_3.csv
# Number of rows: 29
# Number of columns: 1530
#
# File: ./Data\2_4.csv
# Number of rows: 29
# Number of columns: 1530
#
# File: ./Data\2_5.csv
# Number of rows: 29
# Number of columns: 1530
#
# File: ./Data\2_6.csv
# Number of rows: 29
# Number of columns: 1530
#
# File: ./Data\2_7.csv
# Number of rows: 29
# Number of columns: 1530
#
# File: ./Data\2_8.csv
# Number of rows: 29
# Number of columns: 1530
#
# File: ./Data\2_9.csv
# Number of rows: 29
# Number of columns: 1530
#
# File: ./Data\3_1.csv
# Number of rows: 29
# Number of columns: 1530
#
# File: ./Data\3_10.csv
# Number of rows: 29
# Number of columns: 1530
#
# File: ./Data\3_2.csv
# Number of rows: 29
# Number of columns: 1530
#
# File: ./Data\3_3.csv
# Number of rows: 29
# Number of columns: 1530
#
# File: ./Data\3_4.csv
# Number of rows: 29
# Number of columns: 1530
#
# File: ./Data\3_5.csv
# Number of rows: 29
# Number of columns: 1530
#
# File: ./Data\3_6.csv
# Number of rows: 29
# Number of columns: 1530
#
# File: ./Data\3_7.csv
# Number of rows: 29
# Number of columns: 1530
#
# File: ./Data\3_8.csv
# Number of rows: 29
# Number of columns: 1530
#
# File: ./Data\3_9.csv
# Number of rows: 29
# Number of columns: 1530
